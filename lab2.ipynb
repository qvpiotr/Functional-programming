-- %%
myFun x = 2 * x

add2T :: Num a => (a, a) -> a
add2T (x,y) = x + y

add2C :: Num a => a -> a -> a
add2C x y = x + y

add3T :: Num a => (a, a, a) -> a
add3T (x,y,z) = x + y + z

add3C :: Num a => a -> a -> a -> a
add3C x y z = x + y + z

curry2 :: ((a, b) -> c) -> a -> b -> c
curry2 f x y = f (x,y)

uncurry2 :: (a -> b -> c) -> (a, b) -> c
uncurry2 f (x,y) = (f x) y

curry3 :: ((a, b, c) -> d) -> a -> b -> c -> d
curry3 f x y z = f(x,y,z)

uncurry3 :: (a -> b -> c -> d) -> (a, b, c) -> d
uncurry3 f (x,y,z) = ((f x) y) z

-- -> jest prawostronnie łączny

-- main = uncurry2 add2C (1,2)
uncurry3 add3C (1,2,3)
-- Out:
-- Line 19: Redundant bracket
-- Found:
-- (f x) y
-- Why not:
-- f x yLine 25: Redundant bracket
-- Found:
-- ((f x) y) z
-- Why not:
-- (f x) y zLine 25: Redundant bracket
-- Found:
-- (f x) y
-- Why not:
-- f x y
-- 6

-- %%
fiveToPower_ :: Integer -> Integer
fiveToPower_ x = 5^x

_ToPower5 :: Num a => a -> a
_ToPower5 x = x^5

subtrNFrom5 :: Num a => a -> a
subtrNFrom5 x = 5 - x

subtr5From_ :: Num a => a -> a
subtr5From_ x = x - 5

-- %%
isPalindrome :: [Char] -> Bool
isPalindrome x = x == reverse x
isPalindrome "ABBA"
-- Out:
-- Line 1: Use String
-- Found:
-- [Char] -> Bool
-- Why not:
-- String -> Bool
-- True

-- %%
length [(a,b,c) | a <- [1..100], b <- [1..100], c <- [1..100], a^2 + b^2 == c^2]
-- Out:
-- 104

-- %%
isPrime :: Integral t => t -> Bool
isPrime n = [i | i <- [2..n-1], n `mod` i == 0] == []

isPrime 0 --nie jest poprawna
-- Out:
-- Line 2: Use null
-- Found:
-- [i | i <- [2 .. n - 1], n `mod` i == 0] == []
-- Why not:
-- null [i | i <- [2 .. n - 1], n `mod` i == 0]
-- True

-- %%
isPrime :: Integral t => t -> Bool
isPrime 0 = False
isPrime 1 = False
isPrime n = [i | i <- [2..n-1], n `mod` i == 0] == []

isPrime 0
-- Out:
-- Line 4: Use null
-- Found:
-- [i | i <- [2 .. n - 1], n `mod` i == 0] == []
-- Why not:
-- null [i | i <- [2 .. n - 1], n `mod` i == 0]
-- False

-- %%
fib :: (Num a, Eq a) => a -> a
fib n =
 if n == 0 || n == 1 then n
 else fib (n - 2) + fib (n - 1)
 
sum' :: Num a => [a] -> a
sum' []     = 0
sum' (x:xs) = x + sum' xs

prod' :: Num a => [a] -> a
prod' [] = 1
prod' (x:xs) = x * prod' xs

length' :: [a] -> Int
length' [] = 0
length' (_:xs) = 1 + length' xs

or' :: [Bool] -> Bool
or' [] = False
or' (x:xs) = x || or' xs

and' :: [Bool] -> Bool
and' [] = True
and' (x:xs) = x && and' xs

elem' :: Eq a => a -> [a] -> Bool
elem' n [] = False
elem' n (x:xs) = (x == n) || elem' n xs

doubleAll :: Num t => [t] -> [t]
doubleAll [] = []
doubleAll (x:xs) = [2*x] ++ doubleAll xs

squareAll :: Num t => [t] -> [t]
squareAll [] = []
squareAll (x:xs) = [x^2] ++ squareAll xs

selectEven :: Integral t => [t] -> [t]
selectEven [] = []
selectEven (x:xs) | x `mod` 2 == 0 = [x] ++ selectEven xs
                  | otherwise = selectEven xs
-- Out:
-- Line 7: Use foldr
-- Found:
-- sum' [] = 0
-- sum' (x : xs) = x + sum' xs
-- Why not:
-- sum' xs = foldr (+) 0 xsLine 11: Use foldr
-- Found:
-- prod' [] = 1
-- prod' (x : xs) = x * prod' xs
-- Why not:
-- prod' xs = foldr (*) 1 xsLine 19: Use foldr
-- Found:
-- or' [] = False
-- or' (x : xs) = x || or' xs
-- Why not:
-- or' xs = foldr (||) False xsLine 23: Use foldr
-- Found:
-- and' [] = True
-- and' (x : xs) = x && and' xs
-- Why not:
-- and' xs = foldr (&&) True xsLine 27: Use foldr
-- Found:
-- elem' n [] = False
-- elem' n (x : xs) = (x == n) || elem' n xs
-- Why not:
-- elem' n xs = foldr (\ x -> (||) (x == n)) False xsLine 31: Use foldr
-- Found:
-- doubleAll [] = []
-- doubleAll (x : xs) = [2 * x] ++ doubleAll xs
-- Why not:
-- doubleAll xs = foldr (\ x -> (++) [2 * x]) [] xsLine 32: Use :
-- Found:
-- [2 * x] ++ doubleAll xs
-- Why not:
-- (2 * x) : doubleAll xsLine 35: Use foldr
-- Found:
-- squareAll [] = []
-- squareAll (x : xs) = [x ^ 2] ++ squareAll xs
-- Why not:
-- squareAll xs = foldr (\ x -> (++) [x ^ 2]) [] xsLine 36: Use :
-- Found:
-- [x ^ 2] ++ squareAll xs
-- Why not:
-- (x ^ 2) : squareAll xsLine 40: Use :
-- Found:
-- [x] ++ selectEven xs
-- Why not:
-- x : selectEven xs

-- %%
sum'2 :: Num a => [a] -> a
sum'2 xs = loop 0 xs
 where loop acc []     = acc
       loop acc (x:xs) = loop (x + acc) xs
       
sum'3 :: Num a => [a] -> a
sum'3 = loop 0
 where loop acc []     = acc
       loop acc (x:xs) = loop (x + acc) xs
-- Out:
-- Line 2: Eta reduce
-- Found:
-- sum'2 xs = loop 0 xs
-- Why not:
-- sum'2 = loop 0Line 3: Use foldl
-- Found:
-- loop acc [] = acc
-- loop acc (x : xs) = loop (x + acc) xs
-- Why not:
-- loop acc xs = foldl (flip (+)) acc xsLine 8: Use foldl
-- Found:
-- loop acc [] = acc
-- loop acc (x : xs) = loop (x + acc) xs
-- Why not:
-- loop acc xs = foldl (flip (+)) acc xs

-- %%
prod'2 :: Num a => [a] -> a
prod'2 = loop 1
    where loop acc [] = acc
          loop acc (x:xs) = loop (x * acc) xs
-- Out:
-- Line 3: Use foldl
-- Found:
-- loop acc [] = acc
-- loop acc (x : xs) = loop (x * acc) xs
-- Why not:
-- loop acc xs = foldl (flip (*)) acc xs

-- %%
qSort :: Ord a => [a] -> [a]
qSort []     = []
qSort (x:xs) = qSort (leftPart xs) ++ [x] ++ qSort (rightPart xs)
 where
    leftPart xs = filter (<=x) xs
    rightPart xs = filter (>x) xs
-- Out:
-- Line 5: Eta reduce
-- Found:
-- leftPart xs = filter (<= x) xs
-- Why not:
-- leftPart = filter (<= x)Line 6: Eta reduce
-- Found:
-- rightPart xs = filter (> x) xs
-- Why not:
-- rightPart = filter (> x)

-- %%
fst2Eq :: Eq a => [a] -> Bool
fst2Eq (x : y : _) | x == y = True
fst2Eq _                    = False

sndDivByFst :: Integral a => [a] -> Bool
sndDivByFst (x : y : _) | y `mod` x == 0 = True
sndDivByFst _                            = False
